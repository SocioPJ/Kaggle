# %% [markdown]
# DataFrame

# %% [markdown]
# A DataFrame is a table. It contains an array of individual entries, each of which has a certain value. Each entry corresponds to a row (or record) and a column.

# %%
import pandas as pd
pd.DataFrame({'Yes': [50, 21], 'No': [131, 2]})
pd.DataFrame({'Yes': [50, 21], 'No': [131, 2]}, index=['A', 'B'])
# Out:
#    Yes   No
# A   50  131
# B   21    2

# %% [markdown]
# We are using the pd.DataFrame() constructor to generate these DataFrame objects. The syntax for declaring a new one is a dictionary whose keys are the column names (Bob and Sue in this example), and whose values are a list of entries. This is the standard way of constructing a new DataFrame, and the one you are most likely to encounter.

# %%
pd.DataFrame({'Bob': ['I liked it.', 'It was awful.'], 'Sue': ['Pretty good.', 'Bland.']})
# Out:
#              Bob           Sue
# 0    I liked it.  Pretty good.
# 1  It was awful.        Bland.

# %% [markdown]
# fefef

# %%
pd.DataFrame({'Bob': ['I liked it.', 'It was awful.'], 
              'Sue': ['Pretty good.', 'Bland.']},
             index=['Product A', 'Product B'])
# Out:
#                      Bob           Sue
# Product A    I liked it.  Pretty good.
# Product B  It was awful.        Bland.

# %% [markdown]
# Series

# %% [markdown]
# A Series, by contrast, is a sequence of data values. If a DataFrame is a table, a Series is a list. And in fact you can create one with nothing more than a list:

# %%
pd.Series([1 , 2, 3 ,4 , 5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
pd.Series([1 ,2, 3, 4, 5], index=['a', 'b', 'c', 'd', 'e'], name='series_name')
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# Name: series_name, dtype: int64

# %%
pd.Series([30, 35, 40], index=['2015 Sales', '2016 Sales', '2017 Sales'], name='Product A')
# Out:
# 2015 Sales    30
# 2016 Sales    35
# 2017 Sales    40
# Name: Product A, dtype: int64

# %% [markdown]
# Reading Data files

# %% [markdown]
# Being able to create a DataFrame or Series by hand is handy. But, most of the time, we won't actually be creating our own data by hand. Instead, we'll be working with data that already exists.
#
# Data can be stored in any of a number of different forms and formats. By far the most basic of these is the humble CSV file. When you open a CSV file you get something that looks like this:

# %%
pd.read_csv('C:\Prog\Kaggle\Pandas\Create,Reading and Writing\Teoria\Pesquisa - Serviços de Streaming.csv')
# Out:
#      Carimbo de data/hora           \
# 0    2022/05/03 10:21:32 AM GMT-3
# 1    2022/05/03 10:27:36 AM GMT-3
# 2    2022/05/03 10:29:52 AM GMT-3
# 3    2022/05/03 10:49:56 AM GMT-3
# 4    2022/05/03 10:50:22 AM GMT-3
# ..                             ...
# 199  2022/05/04 5:07:18 PM GMT-3
# 200  2022/05/04 6:31:57 PM GMT-3
# 201  2022/05/04 7:55:56 PM GMT-3
# 202  2022/05/04 8:18:09 PM GMT-3
# 203  2022/05/05 1:55:56 AM GMT-3
#
#     Quais serviços você conhece? (selecione uma ou mais)                                        \
# 0    Netflix;Disney+;Star+;Prime Video;HBO Max;Hulu...
# 1    Netflix;Disney+;Prime Video;HBO Max;Hulu;Globo...
# 2    Netflix;Disney+;Star+;Prime Video;HBO Max;Hulu...
# 3    Netflix;Disney+;Star+;Prime Video;HBO Max     ...
# 4    Netflix;Disney+;Star+;Prime Video;HBO Max;Hulu...
# ..                                                 ...
# 199  Netflix;Disney+;Star+;Prime Video;HBO Max;Glob...
# 200  Netflix;Prime Video;HBO Max;Globoplay         ...
# 201  Netflix;Disney+;Star+;Prime Video;Globoplay   ...
# 202  Netflix;Disney+;Star+;Prime Video;HBO Max;Glob...
# 203  Netflix;Disney+;Star+;Prime Video;HBO Max;Hulu...
#
#     Quais serviços você ou sua família assinam? (selecione uma ou mais)               \
# 0    Netflix;Prime Video;HBO Max                   ...
# 1    Netflix;Prime Video;Crunchyroll               ...
# 2    Netflix;Disney+;Star+;Prime Video;HBO Max;NBA ...
# 3    Netflix;Disney+;Prime Video;HBO Max           ...
# 4    Netflix;Disney+;Star+;Prime Video;HBO Max     ...
# ..                                                 ...
# 199  Netflix;Disney+;Star+;HBO Max                 ...
# 200  Netflix;Prime Video;HBO Max                   ...
# 201  Netflix;Star+;Prime Video;Globoplay           ...
# 202  Netflix;Prime Video;Globoplay                 ...
# 203  Netflix;Prime Video;HBO Max                   ...
#
#     Quais serviços você mais gosta? (selecione uma ou mais)   Idade      \
# 0    Disney+;Prime Video                           ...        20
# 1    Netflix;Prime Video;HBO Max                   ...        20
# 2    Netflix;Disney+;Star+;HBO Max                 ...        19
# 3    Netflix;Disney+;HBO Max                       ...        22
# 4    Netflix;Disney+;Prime Video;HBO Max;Globoplay ...        20 anos
# ..                                                 ...              ...
# 199  Netflix;HBO Max                               ...        19
# 200  Netflix;HBO Max                               ...        69
# 201  Netflix;Star+;Globoplay                       ...        54
# 202  Netflix;Globoplay                             ...        40
# 203  Netflix;HBO Max                               ...        22
#
#      Gênero      Ocupação                  \
# 0    Masculino   Estudando
# 1    Masculino   Estudando
# 2    Masculino   Estudando
# 3    Masculino   Estudando e Trabalhando
# 4    Feminino    Estudando e Trabalhando
# ..          ...                       ...
# 199  Masculino   Estudando
# 200  Masculino   Trabalhando
# 201  Feminino    Estudando e Trabalhando
# 202  Masculino   Estudando e Trabalhando
# 203  Feminino    Estudando
#
#     Quantas crianças (menor de 10 anos) moram com você?   \
# 0    0                                             ...
# 1    0                                             ...
# 2    0                                             ...
# 3    0                                             ...
# 4    0                                             ...
# ..                                                 ...
# 199  0                                             ...
# 200  0                                             ...
# 201  0                                             ...
# 202  0                                             ...
# 203  0                                             ...
#
#      Tipo de conteúdo preferido:   \
# 0    Séries
# 1    Séries
# 2    Séries
# 3    Séries
# 4    Séries
# ..                            ...
# 199  Séries
# 200  Filmes
# 201  Filmes
# 202  Filmes
# 203  Séries
#
#      Durante a semana, quantas horas você assiste de streaming por dia?   \
# 0                                                    1
# 1                                                    0
# 2                                                    1
# 3                                                    5
# 4                                                    4
# ..                                                 ...
# 199                                                  1
# 200                                                  1
# 201                                                  6
# 202                                                  2
# 203                                                  6
#
#      De final de semana, quantas horas você assiste de streaming por dia?   \
# 0                                                    2
# 1                                                    1
# 2                                                    1
# 3                                                    6
# 4                                                    6
# ..                                                 ...
# 199                                                  4
# 200                                                  6
# 201                                                  5
# 202                                                  2
# 203                                                  8
#
#     Quais dispositivos você utiliza para assistir streaming? (selecione uma ou mais)   \
# 0    Celular                                       ...
# 1    Smart TV                                      ...
# 2    Smart TV;Google Chromecast ou similar;Tablet o...
# 3    Notebook ou PC                                ...
# 4    Smart TV;Celular                              ...
# ..                                                 ...
# 199  Smart TV;Celular;Notebook ou PC               ...
# 200  Smart TV                                      ...
# 201  Smart TV;Celular;Notebook ou PC               ...
# 202  Smart TV                                      ...
# 203  Smart TV;Google Chromecast ou similar;Notebook...
#
#      Qual preço você julga justo assinar?   Qual sua renda familiar mensal?   \
# 0    R$15,00 - R$25,00                      R$10.000,00 - R$20.000,00
# 1    R$15,00 - R$25,00                      Mais de R$20.000,00
# 2    R$15,00 - R$25,00                      R$10.000,00 - R$20.000,00
# 3    R$25,00 - R$35,00                      R$1.000,00 - R$5.000,00
# 4    R$15,00 - R$25,00                      R$5.000,00 - R$10.000,00
# ..                                     ...                               ...
# 199  R$15,00 - R$25,00                      R$10.000,00 - R$20.000,00
# 200  R$25,00 - R$35,00                      Mais de R$20.000,00
# 201  R$15,00 - R$25,00                      R$10.000,00 - R$20.000,00
# 202  R$25,00 - R$35,00                      R$10.000,00 - R$20.000,00
# 203  R$15,00 - R$25,00                      R$1.000,00 - R$5.000,00
#
#     O que poderia melhorar nos serviços de streaming que você assina?
# 0                    Maior catálogo de filmes e séries
# 1    Maior catálogo de filmes e séries;Conexão;Inte...
# 2                                                Preço
# 3              Preço;Maior catálogo de filmes e séries
# 4              Preço;Maior catálogo de filmes e séries
# ..                                                 ...
# 199                                    Preço;Interface
# 200                  Maior catálogo de filmes e séries
# 201            Preço;Maior catálogo de filmes e séries
# 202                  Maior catálogo de filmes e séries
# 203                                              Preço
#
# [204 rows x 15 columns]

# %% [markdown]
# We can use the shape attribute to check how large the resulting DataFrame is:

# %%
file = pd.read_csv('C:\Prog\Kaggle\Pandas\Create,Reading and Writing\Teoria\Pesquisa - Serviços de Streaming.csv')
file.shape
# Out:
# (204, 15)

# %% [markdown]
# We can examine the contents of the resultant DataFrame using the head() command, which grabs the first five rows:

# %%
file.head()
# Out:
#    Carimbo de data/hora           \
# 0  2022/05/03 10:21:32 AM GMT-3
# 1  2022/05/03 10:27:36 AM GMT-3
# 2  2022/05/03 10:29:52 AM GMT-3
# 3  2022/05/03 10:49:56 AM GMT-3
# 4  2022/05/03 10:50:22 AM GMT-3
#
#   Quais serviços você conhece? (selecione uma ou mais)                                        \
# 0  Netflix;Disney+;Star+;Prime Video;HBO Max;Hulu...
# 1  Netflix;Disney+;Prime Video;HBO Max;Hulu;Globo...
# 2  Netflix;Disney+;Star+;Prime Video;HBO Max;Hulu...
# 3  Netflix;Disney+;Star+;Prime Video;HBO Max     ...
# 4  Netflix;Disney+;Star+;Prime Video;HBO Max;Hulu...
#
#   Quais serviços você ou sua família assinam? (selecione uma ou mais)               \
# 0  Netflix;Prime Video;HBO Max                   ...
# 1  Netflix;Prime Video;Crunchyroll               ...
# 2  Netflix;Disney+;Star+;Prime Video;HBO Max;NBA ...
# 3  Netflix;Disney+;Prime Video;HBO Max           ...
# 4  Netflix;Disney+;Star+;Prime Video;HBO Max     ...
#
#   Quais serviços você mais gosta? (selecione uma ou mais)   Idade      \
# 0  Disney+;Prime Video                           ...        20
# 1  Netflix;Prime Video;HBO Max                   ...        20
# 2  Netflix;Disney+;Star+;HBO Max                 ...        19
# 3  Netflix;Disney+;HBO Max                       ...        22
# 4  Netflix;Disney+;Prime Video;HBO Max;Globoplay ...        20 anos
#
#    Gênero      Ocupação                  \
# 0  Masculino   Estudando
# 1  Masculino   Estudando
# 2  Masculino   Estudando
# 3  Masculino   Estudando e Trabalhando
# 4  Feminino    Estudando e Trabalhando
#
#   Quantas crianças (menor de 10 anos) moram com você?   \
# 0  0                                             ...
# 1  0                                             ...
# 2  0                                             ...
# 3  0                                             ...
# 4  0                                             ...
#
#    Tipo de conteúdo preferido:   \
# 0  Séries
# 1  Séries
# 2  Séries
# 3  Séries
# 4  Séries
#
#    Durante a semana, quantas horas você assiste de streaming por dia?   \
# 0                                                  1
# 1                                                  0
# 2                                                  1
# 3                                                  5
# 4                                                  4
#
#    De final de semana, quantas horas você assiste de streaming por dia?   \
# 0                                                  2
# 1                                                  1
# 2                                                  1
# 3                                                  6
# 4                                                  6
#
#   Quais dispositivos você utiliza para assistir streaming? (selecione uma ou mais)   \
# 0  Celular                                       ...
# 1  Smart TV                                      ...
# 2  Smart TV;Google Chromecast ou similar;Tablet o...
# 3  Notebook ou PC                                ...
# 4  Smart TV;Celular                              ...
#
#    Qual preço você julga justo assinar?   Qual sua renda familiar mensal?   \
# 0  R$15,00 - R$25,00                      R$10.000,00 - R$20.000,00
# 1  R$15,00 - R$25,00                      Mais de R$20.000,00
# 2  R$15,00 - R$25,00                      R$10.000,00 - R$20.000,00
# 3  R$25,00 - R$35,00                      R$1.000,00 - R$5.000,00
# 4  R$15,00 - R$25,00                      R$5.000,00 - R$10.000,00
#
#   O que poderia melhorar nos serviços de streaming que você assina?
# 0                  Maior catálogo de filmes e séries
# 1  Maior catálogo de filmes e séries;Conexão;Inte...
# 2                                              Preço
# 3            Preço;Maior catálogo de filmes e séries
# 4            Preço;Maior catálogo de filmes e séries

# %%
file = pd.read_csv('C:\Prog\Kaggle\Pandas\Create,Reading and Writing\Teoria\Pesquisa - Serviços de Streaming.csv',index_col=0)
file.head()
# Out:
#                               Quais serviços você conhece? (selecione uma ou mais)                                        \
# Carimbo de data/hora
# 2022/05/03 10:21:32 AM GMT-3   Netflix;Disney+;Star+;Prime Video;HBO Max;Hulu...
# 2022/05/03 10:27:36 AM GMT-3   Netflix;Disney+;Prime Video;HBO Max;Hulu;Globo...
# 2022/05/03 10:29:52 AM GMT-3   Netflix;Disney+;Star+;Prime Video;HBO Max;Hulu...
# 2022/05/03 10:49:56 AM GMT-3   Netflix;Disney+;Star+;Prime Video;HBO Max     ...
# 2022/05/03 10:50:22 AM GMT-3   Netflix;Disney+;Star+;Prime Video;HBO Max;Hulu...
#
#                               Quais serviços você ou sua família assinam? (selecione uma ou mais)               \
# Carimbo de data/hora
# 2022/05/03 10:21:32 AM GMT-3   Netflix;Prime Video;HBO Max                   ...
# 2022/05/03 10:27:36 AM GMT-3   Netflix;Prime Video;Crunchyroll               ...
# 2022/05/03 10:29:52 AM GMT-3   Netflix;Disney+;Star+;Prime Video;HBO Max;NBA ...
# 2022/05/03 10:49:56 AM GMT-3   Netflix;Disney+;Prime Video;HBO Max           ...
# 2022/05/03 10:50:22 AM GMT-3   Netflix;Disney+;Star+;Prime Video;HBO Max     ...
#
#                               Quais serviços você mais gosta? (selecione uma ou mais)   \
# Carimbo de data/hora
# 2022/05/03 10:21:32 AM GMT-3   Disney+;Prime Video                           ...
# 2022/05/03 10:27:36 AM GMT-3   Netflix;Prime Video;HBO Max                   ...
# 2022/05/03 10:29:52 AM GMT-3   Netflix;Disney+;Star+;HBO Max                 ...
# 2022/05/03 10:49:56 AM GMT-3   Netflix;Disney+;HBO Max                       ...
# 2022/05/03 10:50:22 AM GMT-3   Netflix;Disney+;Prime Video;HBO Max;Globoplay ...
#
#                                Idade      Gênero      \
# Carimbo de data/hora
# 2022/05/03 10:21:32 AM GMT-3   20         Masculino
# 2022/05/03 10:27:36 AM GMT-3   20         Masculino
# 2022/05/03 10:29:52 AM GMT-3   19         Masculino
# 2022/05/03 10:49:56 AM GMT-3   22         Masculino
# 2022/05/03 10:50:22 AM GMT-3   20 anos    Feminino
#
#                                Ocupação                  \
# Carimbo de data/hora
# 2022/05/03 10:21:32 AM GMT-3